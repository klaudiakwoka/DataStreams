# %%
import pandas as pd
from utils import plot_compare_models

# %%
df = pd.read_csv('results/compare_models/taxi_1million.csv')
df[df.y_ARF != df.y_ARF_drift]
# Out:
# Empty DataFrame
# Columns: [i, timestamp, y_true, y_MEAN, y_HTR, y_ARF, y_ARF_drift, y_SRP, y_SRP_drift, y_Ensemble]
# Index: []

# %%
res = plot_compare_models(df, 
                    start_date='2016-04-01',
                    end_date='2016-04-30',
                    window=20000, 
                    # resample_rule='1D',
                    # log_scale=True
                    # save_path='plots/compare_models/warsaw_w20_20250424.png'
                   )

# %%
df = pd.read_csv('results/compare_models/warsaw_no_max_depth_adwin_5.csv')
df[df.y_ARF != df.y_ARF_drift]
# Out:
#              i            timestamp     y_true     y_MEAN      y_HTR  \
# 2895      2895  2025-01-04 23:00:00  12.649263  35.180998  24.926916
# 2897      2897  2025-01-04 23:00:00  10.479844  35.168410   8.643371
# 2899      2899  2025-01-04 23:00:00  25.157388  35.154995  31.554483
# 2901      2901  2025-01-04 23:00:00  10.063127  35.151672  24.904095
# 2902      2902  2025-01-04 23:00:00  15.031696  35.143026  24.876561
# ...        ...                  ...        ...        ...        ...
# 298247  298247  2025-12-31 23:00:00  53.196573  33.481844  36.860410
# 298248  298248  2025-12-31 23:00:00  26.696902  33.481910  16.237895
# 298249  298249  2025-12-31 23:00:00   2.420534  33.481888   3.311253
# 298250  298250  2025-12-31 23:00:00  22.002389  33.481784  18.138574
# 298251  298251  2025-12-31 23:00:00  27.046048  33.481745  23.089798
#
#             y_ARF  y_ARF_drift      y_SRP  y_SRP_drift  y_Ensemble
# 2895    18.648255    18.653249  17.127417    20.068089   21.610995
# ...

# %%
res = plot_compare_models(df, 
                    start_date='2025-12-01',
                    end_date='2025-12-31',
                    window=2000, 
                    # resample_rule='1D',
                    save_path='plots/compare_models/warsaw_w2000_202512.png'
                   )

# %%
df = pd.read_csv('results/compare_models/airline.csv')
df[df.y_ARF != df.y_ARF_drift]
# Out:
# Empty DataFrame
# Columns: [i, timestamp, y_true, y_MEAN, y_HTR, y_ARF, y_ARF_drift, y_SRP, y_SRP_drift, y_Ensemble]
# Index: []

# %%
res = plot_compare_models(df, 
                    start_date='2008-01-20',
                    end_date='2008-01-25',
                    window=1000, 
                    # resample_rule='h',
                    # log_scale=True,
                    # save_path='plots/compare_models/airline_w10000_20080120_20080125.png'
                   )

# %%
df[df.y_HTR != df.y_Ensemble]
# Out:
#              i            timestamp  y_true    y_MEAN      y_HTR      y_ARF  \
# 1786      1786  2008-01-01 07:00:00   -17.0  8.933931  -2.751468  -6.941794
# 1787      1787  2008-01-01 07:00:00     2.0  8.919418   7.165957  15.423980
# 1788      1788  2008-01-01 07:00:00    23.0  8.915548  18.316810  -2.169721
# 1789      1789  2008-01-01 07:00:00     9.0  8.923421   7.154989   2.344691
# 1790      1790  2008-01-01 07:00:00    -3.0  8.923464  12.567164   1.373523
# ...        ...                  ...     ...       ...        ...        ...
# 499994  499994  2008-01-27 12:00:00     5.0  9.595695   7.412192   3.908668
# 499995  499995  2008-01-27 12:00:00   -10.0  9.595686 -12.953488  -2.215146
# 499996  499996  2008-01-27 12:00:00   240.0  9.595647  20.336767  12.482671
# 499997  499997  2008-01-27 12:00:00     4.0  9.596108 -12.944928   0.138889
# 499998  499998  2008-01-27 12:00:00   -22.0  9.596096  -6.868293  -0.796429
#
#         y_ARF_drift       y_SRP  y_SRP_drift  y_Ensemble
# ...
